# %%
#write a python program that accepts an integer n and computes the value of n+nn+nnn=?

# %%
n1=int(input("Enter the number"))
nn=n1*11
nnn=n1*111
result=n1+nn+nnn
print(n1,"+", nn,"+", nnn, "=",result)
# Out:
# Enter the number 5
# 5 + 55 + 555 = 615

# %%
#input the raduis of a circle and computes the area (importh math)

# %%
import math
r=float(input("Enter the radius"))
area=round(math.pi *r*r)
print("the area is:",area)
# Out:
# Enter the radius 5
# the area is: 79

# %%
#write a program to find the biggest of three numbers(use max)))

# %%
n1=int(input("enter the first number"))
n2=int(input("enter the second number"))
n3=int(input("enter the third number"))
biggest=max(n1,n2,n3)
print("biggest number is:",biggest)
# Out:
# enter the first number 5
# enter the second number 9
# enter the third number 8
# biggest number is: 9
