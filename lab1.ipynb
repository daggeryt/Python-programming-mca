# %%
age=input("Enter your age:")
print("Hello",age)
# Out:
# Enter your age: 5522
# Hello 5522

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
n1=int(input("enter you first numer"))
n2=int(input("enter you second numer"))
sum=n1+n2
print("sum:",sum)
# Out:
# enter you first numer 5
# enter you second numer 5
# sum: 10

# %%
import math
n1=int(input("enter your number"))
result=(math.sqrt(n1))
print(f"{result:.2f}")
# Out:
# enter your number 5
# 2.24
